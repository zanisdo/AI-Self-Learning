# %% [markdown]
# <a href="https://colab.research.google.com/github/Chien141/AI-Self-Learning/blob/main/Day_1_Python_Review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 0

def aplus( a ):
  return a + 1

print (aplus(aplus(a)))
# Out:
# 2
